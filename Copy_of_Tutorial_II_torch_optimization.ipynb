# %% [markdown]
# <a href="https://colab.research.google.com/github/m-rappo/CAS_ADS/blob/main/Copy_of_Tutorial_II_torch_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tutorial II: Optimization in **pytorch** and NN introduction
#
# <p>
# Bern Winter School on Machine Learning, 2024<br>
# Prepared by Mykhailo Vladymyrov and Matthew Vowels.
# </p>
#
# This work is licensed under a <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %%
# time to teach without exercises 50mins

# %% [markdown]
# ## 1. Load necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## 2. Linear fit
#
# Here we will solve optimization problem to perform linear regression. First we will generate training set of 80 data points and test set of 20, laying on a line with a random offset $$y = a_0 x + b_0 + \delta,$$ where $\delta$ is a random variable sampled from a uniform distribution with standard deviation equal to $s_0$.
# <!-- o.f.: 46, 48, 87, 99 | val better than train: 47, 56, 86. -->

# %%
a0 = 3  # 3
b0 = 5  # 5
s0 = 1  # 1

n_all = 100

np.random.seed(99)

# all samples
x_all = np.linspace(0, 10, n_all)  # 100 points
d_all = np.random.uniform(-s0, s0, size=n_all)
y_all = np.asarray([a0*np.sin(x) + x + b0 + d for x, d in zip(x_all, d_all)])

# randomize order and get 80% for training
idx = np.random.permutation(n_all)
n_train = n_all * 80 // 100

idx_train = idx[0:n_train]
idx_val = idx[n_train:]

x_train, y_train = x_all[idx_train], y_all[idx_train]

x_val, y_val = x_all[idx_val], y_all[idx_val]

plt.plot(x_train, y_train, "or", x_val, y_val, "b^")
plt.legend(('training points', 'validation points'),  loc='upper left');

# %% [markdown]
# We will then define loss function as the mean of squared residuals (distance from line along $y$) for the points.
#
# We will use [stochactic gradient descent](https://en.wikipedia.org/wiki/Stochastic_gradient_descent): on each iteration use only a fraction (`batch_size`) of all training set. In many cases training set is huge and cannot be fed on each iteration in principle. Also it can sometimes help the optimizer to properly explore the manifold.

# %%
class Linear(nn.Module):
    def __init__(self):
        super(Linear, self).__init__()
        self.a = nn.Parameter(torch.randn(1, requires_grad=True))
        self.b = nn.Parameter(torch.randn(1, requires_grad=True))

    def forward(self, x):
        return self.a * x + self.b


def loss_f(true_y, y_predicted):
    return F.mse_loss(y_predicted, true_y) # torch.mean((y_predicted - true_y)**2)

# %%
# Define the model
model = Linear()

# Define the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.002)

# Define the number of epochs and batch size
epochs = 400
batch_size = 10


x_train = torch.tensor(x_train)  # watch out for d-type issues with torch.tensors
y_train = torch.tensor(y_train)

x_val = torch.tensor(x_val)
y_val = torch.tensor(y_val)


# Training loop
train_loss_history = []
val_loss_history = []

for epoch in range(epochs):
    model.train()  # as opposed to model.eval()
    batch_losses = []
    permutation = torch.randperm(x_train.size()[0])


    for i in range(0, x_train.size()[0], batch_size):
        optimizer.zero_grad()

        indices = permutation[i:i+batch_size]
        batch_x, batch_y = x_train[indices], y_train[indices]

        # Forward pass
        outputs = model(batch_x)

        # Compute the loss
        loss = loss_f(batch_y, outputs)
        batch_losses.append(loss.item())
        # Backward pass and optimization
        loss.backward()
        optimizer.step()

    average_training_loss = np.mean(batch_losses)
    train_loss_history.append(average_training_loss)

    # Validation step (optional, for monitoring performance)
    model.eval()
    with torch.no_grad():
        val_outputs = model(x_val)
        val_loss = loss_f(y_val, val_outputs)
        val_loss_history.append(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {val_loss.item()}")
# Out:
# Epoch 1/400, Validation Loss: 28.269428192766192
# Epoch 2/400, Validation Loss: 13.28347629988618
# Epoch 3/400, Validation Loss: 11.89429986944128
# Epoch 4/400, Validation Loss: 11.586797955617044
# Epoch 5/400, Validation Loss: 11.46267357679232
# Epoch 6/400, Validation Loss: 11.341269983359057
# Epoch 7/400, Validation Loss: 11.22245906774063
# Epoch 8/400, Validation Loss: 11.103768966944932
# Epoch 9/400, Validation Loss: 10.98795382649724
# Epoch 10/400, Validation Loss: 10.874699575366988
# Epoch 11/400, Validation Loss: 10.76161959283257
# Epoch 12/400, Validation Loss: 10.655287538776664
# Epoch 13/400, Validation Loss: 10.543936693235455
# Epoch 14/400, Validation Loss: 10.438504088565846
# Epoch 15/400, Validation Loss: 10.329524718143977
# Epoch 16/400, Validation Loss: 10.242367139164212
# Epoch 17/400, Validation Loss: 10.133652499991463
# Epoch 18/400, Validation Loss: 10.02207603973089
# Epoch 19/400, Validation Loss: 9.923383387189588
# Epoch 20/400, Validation Loss: 9.826592704202437
# Epoch 21/400, Validation Loss: 9.728723192365548
# Epoch 22/400, Validation Loss: 9.635500733413254
# Epoch 23/400, Validation Loss: 9.541281185773428
# Epoch 24/400, Validation Loss: 9.448975731613048
# Epoch 25/400, Validation Loss: 9.358577336283936
# Epoch 26/400, Validation Loss: 9.26970563895488
# Epoch 27/400, Validation Loss: 9.18649341744112
# Epoch 28/400, Validation Loss: 9.099057383652703
# Epoch 29/400, Validation Loss: 9.012827249817194
# Epoch 30/400, Validation Loss: 8.927659887256134
# Epoch 31/400, Validation Loss: 8.847700388434372
# Epoch 32/400, Validation Loss: 8.765663216701377
# Epoch 33/400, Validation Loss: 8.68569734699461
# Epoch 34/400, Validation Loss: 8.614884095920907
# Epoch 35/400, Validation Loss: 8.52937749578729
# Epoch 36/400, Validation Loss: 8.45686425977328
# Epoch 37/400, Validation Loss: 8.378764813609177
# Epoch 38/400, Validation Loss: 8.304801307683281
# Epoch 39/400, Validation Loss: 8.239336197480696
# Epoch 40/400, Validation Loss: 8.166528347933845
# Epoch 41/400, Validation Loss: 8.090504341135183
# Epoch 42/400, Validation Loss: 8.024262321247761
# Epoch 43/400, Validation Loss: 7.954121740204928
# Epoch 44/400, Validation Loss: 7.885721379830391
# Epoch 45/400, Validation Loss: 7.818740517947097
# Epoch 46/400, Validation Loss: 7.754285216909817
# Epoch 47/400, Validation Loss: 7.689879101257705
# Epoch 48/400, Validation Loss: 7.627166303219498
# Epoch 49/400, Validation Loss: 7.571657027305315
# Epoch 50/400, Validation Loss: 7.524736582674862
# Epoch 51/400, Validation Loss: 7.447470807577531
# Epoch 52/400, Validation Loss: 7.387662704111472
# Epoch 53/400, Validation Loss: 7.328814392788148
# Epoch 54/400, Validation Loss: 7.287778386976673
# Epoch 55/400, Validation Loss: 7.215736626889134
# Epoch 56/400, Validation Loss: 7.1613319396822686
# Epoch 57/400, Validation Loss: 7.100113842433454
# Epoch 58/400, Validation Loss: 7.055628818546628
# Epoch 59/400, Validation Loss: 6.993067941788882
# Epoch 60/400, Validation Loss: 6.94381152341906
# Epoch 61/400, Validation Loss: 6.900038960430193
# Epoch 62/400, Validation Loss: 6.849865166953895
# Epoch 63/400, Validation Loss: 6.7905459071356065
# Epoch 64/400, Validation Loss: 6.745403760216109
# Epoch 65/400, Validation Loss: 6.714116757893811
# Epoch 66/400, Validation Loss: 6.642038065129571
# Epoch 67/400, Validation Loss: 6.604620094854971
# Epoch 68/400, Validation Loss: 6.572469262285173
# Epoch 69/400, Validation Loss: 6.50397075113676
# Epoch 70/400, Validation Loss: 6.461659620588167
# Epoch 71/400, Validation Loss: 6.426527837627257
# Epoch 72/400, Validation Loss: 6.370359033800656
# Epoch 73/400, Validation Loss: 6.344625763496644
# Epoch 74/400, Validation Loss: 6.286495070891313
# Epoch 75/400, Validation Loss: 6.2435986149733935
# Epoch 76/400, Validation Loss: 6.213067280941678
# Epoch 77/400, Validation Loss: 6.166274027554137
# Epoch 78/400, Validation Loss: 6.123047572833692
# Epoch 79/400, Validation Loss: 6.082663072895955
# Epoch 80/400, Validation Loss: 6.046383077742451
# Epoch 81/400, Validation Loss: 6.013155895056338
# Epoch 82/400, Validation Loss: 5.9711820712041
# Epoch 83/400, Validation Loss: 5.935157379163615
# Epoch 84/400, Validation Loss: 5.896466647926634
# Epoch 85/400, Validation Loss: 5.86251630636948
# Epoch 86/400, Validation Loss: 5.825308874923667
# Epoch 87/400, Validation Loss: 5.819506164491667
# Epoch 88/400, Validation Loss: 5.759011603678828
# Epoch 89/400, Validation Loss: 5.729445544113358
# Epoch 90/400, Validation Loss: 5.6929053132986045
# Epoch 91/400, Validation Loss: 5.667015017394717
# Epoch 92/400, Validation Loss: 5.624716629794056
# Epoch 93/400, Validation Loss: 5.593185380293173
# Epoch 94/400, Validation Loss: 5.5614254055070464
# Epoch 95/400, Validation Loss: 5.5499078410664575
# Epoch 96/400, Validation Loss: 5.503741131663281
# Epoch 97/400, Validation Loss: 5.4725572130628946
# Epoch 98/400, Validation Loss: 5.442864494051785
# Epoch 99/400, Validation Loss: 5.4134760028715245
# Epoch 100/400, Validation Loss: 5.385093212071068
# Epoch 101/400, Validation Loss: 5.361951635254821
# Epoch 102/400, Validation Loss: 5.328911627810937
# Epoch 103/400, Validation Loss: 5.303343569923799
# Epoch 104/400, Validation Loss: 5.27698213735934
# Epoch 105/400, Validation Loss: 5.258317123028106
# Epoch 106/400, Validation Loss: 5.233048838880723
# Epoch 107/400, Validation Loss: 5.220466485553332
# Epoch 108/400, Validation Loss: 5.179899604890431
# Epoch 109/400, Validation Loss: 5.15968741444981
# Epoch 110/400, Validation Loss: 5.131004814543534
# Epoch 111/400, Validation Loss: 5.100063458598677
# Epoch 112/400, Validation Loss: 5.082065292768744
# Epoch 113/400, Validation Loss: 5.057599010501129
# Epoch 114/400, Validation Loss: 5.032069742533023
# Epoch 115/400, Validation Loss: 5.024098454236295
# Epoch 116/400, Validation Loss: 4.985895006251836
# Epoch 117/400, Validation Loss: 4.9623376964559425
# Epoch 118/400, Validation Loss: 4.953719874497027
# Epoch 119/400, Validation Loss: 4.9190274277951564
# Epoch 120/400, Validation Loss: 4.9195005511851635
# Epoch 121/400, Validation Loss: 4.898582150970878
# Epoch 122/400, Validation Loss: 4.859056644940272
# Epoch 123/400, Validation Loss: 4.83639099594625
# Epoch 124/400, Validation Loss: 4.822937585606004
# Epoch 125/400, Validation Loss: 4.800888838896162
# Epoch 126/400, Validation Loss: 4.778033227351658
# Epoch 127/400, Validation Loss: 4.762602227334116
# Epoch 128/400, Validation Loss: 4.743525186346426
# Epoch 129/400, Validation Loss: 4.723019530648395
# Epoch 130/400, Validation Loss: 4.703925023942961
# Epoch 131/400, Validation Loss: 4.686235521268874
# Epoch 132/400, Validation Loss: 4.672150393633471
# Epoch 133/400, Validation Loss: 4.651075705978429
# Epoch 134/400, Validation Loss: 4.637810089817008
# Epoch 135/400, Validation Loss: 4.622373050121799
# Epoch 136/400, Validation Loss: 4.606298725543354
# Epoch 137/400, Validation Loss: 4.587432860856433
# Epoch 138/400, Validation Loss: 4.57398512674144
# Epoch 139/400, Validation Loss: 4.574890058479971
# Epoch 140/400, Validation Loss: 4.5455718793061575
# Epoch 141/400, Validation Loss: 4.531982636338581
# Epoch 142/400, Validation Loss: 4.507778817406217
# Epoch 143/400, Validation Loss: 4.492274151340438
# Epoch 144/400, Validation Loss: 4.487530765597925
# Epoch 145/400, Validation Loss: 4.468549657484289
# Epoch 146/400, Validation Loss: 4.476644642433373
# Epoch 147/400, Validation Loss: 4.465163770895289
# Epoch 148/400, Validation Loss: 4.4355320257465305
# Epoch 149/400, Validation Loss: 4.424439810564283
# Epoch 150/400, Validation Loss: 4.417884932647713
# Epoch 151/400, Validation Loss: 4.3858458953513875
# Epoch 152/400, Validation Loss: 4.371185844115923
# Epoch 153/400, Validation Loss: 4.3627423942103425
# Epoch 154/400, Validation Loss: 4.350069004487155
# Epoch 155/400, Validation Loss: 4.334203969107504
# Epoch 156/400, Validation Loss: 4.335807982767479
# Epoch 157/400, Validation Loss: 4.313991215727589
# Epoch 158/400, Validation Loss: 4.299348888065465
# Epoch 159/400, Validation Loss: 4.289669988170931
# Epoch 160/400, Validation Loss: 4.2889964782370935
# Epoch 161/400, Validation Loss: 4.270388302303266
# Epoch 162/400, Validation Loss: 4.248199935996616
# Epoch 163/400, Validation Loss: 4.240313604790983
# Epoch 164/400, Validation Loss: 4.227869476736897
# Epoch 165/400, Validation Loss: 4.230304297859682
# Epoch 166/400, Validation Loss: 4.210940766637227
# Epoch 167/400, Validation Loss: 4.193091349585821
# Epoch 168/400, Validation Loss: 4.183619370786627
# Epoch 169/400, Validation Loss: 4.172925190560248
# Epoch 170/400, Validation Loss: 4.163696977966105
# Epoch 171/400, Validation Loss: 4.159509820785103
# Epoch 172/400, Validation Loss: 4.1429641329474975
# Epoch 173/400, Validation Loss: 4.133385039639853
# Epoch 174/400, Validation Loss: 4.124113538625748
# Epoch 175/400, Validation Loss: 4.119615819302032
# Epoch 176/400, Validation Loss: 4.123129590858133
# Epoch 177/400, Validation Loss: 4.119486544084671
# Epoch 178/400, Validation Loss: 4.142190131533707
# Epoch 179/400, Validation Loss: 4.0918443063396435
# Epoch 180/400, Validation Loss: 4.072639018705481
# Epoch 181/400, Validation Loss: 4.062213590424099
# Epoch 182/400, Validation Loss: 4.059568681033678
# Epoch 183/400, Validation Loss: 4.051994960049443
# Epoch 184/400, Validation Loss: 4.036841472764239
# Epoch 185/400, Validation Loss: 4.045620963582949
# Epoch 186/400, Validation Loss: 4.022661717855865
# Epoch 187/400, Validation Loss: 4.0177872480075525
# Epoch 188/400, Validation Loss: 4.00533014733396
# Epoch 189/400, Validation Loss: 4.002207588370064
# Epoch 190/400, Validation Loss: 3.990392111783398
# Epoch 191/400, Validation Loss: 3.9858982850509945
# Epoch 192/400, Validation Loss: 3.983721379649027
# Epoch 193/400, Validation Loss: 3.980002231743819
# Epoch 194/400, Validation Loss: 3.963757664907438
# Epoch 195/400, Validation Loss: 3.958952272450266
# Epoch 196/400, Validation Loss: 3.956446367459949
# Epoch 197/400, Validation Loss: 3.944788532572827
# Epoch 198/400, Validation Loss: 3.934359430861317
# Epoch 199/400, Validation Loss: 3.9270860202411777
# Epoch 200/400, Validation Loss: 3.926174247215554
# Epoch 201/400, Validation Loss: 3.934269445287631
# Epoch 202/400, Validation Loss: 3.93007152404146
# Epoch 203/400, Validation Loss: 3.9086867144474935
# Epoch 204/400, Validation Loss: 3.898936843847268
# Epoch 205/400, Validation Loss: 3.8909812295881165
# Epoch 206/400, Validation Loss: 3.8837818705807607
# Epoch 207/400, Validation Loss: 3.894465691413669
# Epoch 208/400, Validation Loss: 3.8758861360544747
# Epoch 209/400, Validation Loss: 3.888796963050825
# Epoch 210/400, Validation Loss: 3.866872254291362
# Epoch 211/400, Validation Loss: 3.8767130354685277
# Epoch 212/400, Validation Loss: 3.8534517000986286
# Epoch 213/400, Validation Loss: 3.847136730861377
# Epoch 214/400, Validation Loss: 3.8447311320446396
# Epoch 215/400, Validation Loss: 3.840798012161059
# Epoch 216/400, Validation Loss: 3.851807168133284
# Epoch 217/400, Validation Loss: 3.832355897963988
# Epoch 218/400, Validation Loss: 3.8180586973452
# Epoch 219/400, Validation Loss: 3.815143867796537
# Epoch 220/400, Validation Loss: 3.8167903819570994
# Epoch 221/400, Validation Loss: 3.8131234570796986
# Epoch 222/400, Validation Loss: 3.80110104692791
# Epoch 223/400, Validation Loss: 3.793965235673918
# Epoch 224/400, Validation Loss: 3.789132651159189
# Epoch 225/400, Validation Loss: 3.784987920907697
# Epoch 226/400, Validation Loss: 3.7891778313919593
# Epoch 227/400, Validation Loss: 3.827282589142638
# Epoch 228/400, Validation Loss: 3.7870495005316642
# Epoch 229/400, Validation Loss: 3.785314130062485
# Epoch 230/400, Validation Loss: 3.764948602845397
# Epoch 231/400, Validation Loss: 3.759805439659045
# Epoch 232/400, Validation Loss: 3.7589021147190733
# Epoch 233/400, Validation Loss: 3.7596734207222307
# Epoch 234/400, Validation Loss: 3.7487034975871807
# Epoch 235/400, Validation Loss: 3.7592198275577218
# Epoch 236/400, Validation Loss: 3.777942746372239
# Epoch 237/400, Validation Loss: 3.7399312013254273
# Epoch 238/400, Validation Loss: 3.7390239683914572
# Epoch 239/400, Validation Loss: 3.72637149772641
# Epoch 240/400, Validation Loss: 3.723744848478507
# Epoch 241/400, Validation Loss: 3.722037698139089
# Epoch 242/400, Validation Loss: 3.7215010239005606
# Epoch 243/400, Validation Loss: 3.7275393153000698
# Epoch 244/400, Validation Loss: 3.7240353598739646
# Epoch 245/400, Validation Loss: 3.704913196620615
# Epoch 246/400, Validation Loss: 3.70796077552128
# Epoch 247/400, Validation Loss: 3.709460116791014
# Epoch 248/400, Validation Loss: 3.7015028629726863
# Epoch 249/400, Validation Loss: 3.6986346542988606
# Epoch 250/400, Validation Loss: 3.694205868548262
# Epoch 251/400, Validation Loss: 3.697939288138641
# Epoch 252/400, Validation Loss: 3.6818268944098187
# Epoch 253/400, Validation Loss: 3.680297505483106
# Epoch 254/400, Validation Loss: 3.699080549857753
# Epoch 255/400, Validation Loss: 3.6840116284830287
# Epoch 256/400, Validation Loss: 3.676206329820464
# Epoch 257/400, Validation Loss: 3.675341598874425
# Epoch 258/400, Validation Loss: 3.664488390504215
# Epoch 259/400, Validation Loss: 3.6714313943584984
# Epoch 260/400, Validation Loss: 3.6698679101861424
# Epoch 261/400, Validation Loss: 3.6723496282700894
# Epoch 262/400, Validation Loss: 3.6559143281099757
# Epoch 263/400, Validation Loss: 3.6773819931724816
# Epoch 264/400, Validation Loss: 3.648467014585907
# Epoch 265/400, Validation Loss: 3.6637739979105852
# Epoch 266/400, Validation Loss: 3.651813166394504
# Epoch 267/400, Validation Loss: 3.6498648610569537
# Epoch 268/400, Validation Loss: 3.6640907876680964
# Epoch 269/400, Validation Loss: 3.6535829954358183
# Epoch 270/400, Validation Loss: 3.6476448817906424
# Epoch 271/400, Validation Loss: 3.63464652830912
# Epoch 272/400, Validation Loss: 3.631852335446812
# Epoch 273/400, Validation Loss: 3.6240391781493635
# Epoch 274/400, Validation Loss: 3.627680862617269
# Epoch 275/400, Validation Loss: 3.644792903907959
# Epoch 276/400, Validation Loss: 3.622611679946395
# Epoch 277/400, Validation Loss: 3.6162420852240387
# Epoch 278/400, Validation Loss: 3.619914668466909
# Epoch 279/400, Validation Loss: 3.6216851663505
# Epoch 280/400, Validation Loss: 3.608521425636821
# Epoch 281/400, Validation Loss: 3.6093932383842793
# Epoch 282/400, Validation Loss: 3.610856604267121
# Epoch 283/400, Validation Loss: 3.6074308238005677
# Epoch 284/400, Validation Loss: 3.6046567975630888
# Epoch 285/400, Validation Loss: 3.602561431286694
# Epoch 286/400, Validation Loss: 3.611783062335248
# Epoch 287/400, Validation Loss: 3.5996776602854403
# Epoch 288/400, Validation Loss: 3.6341785011116636
# Epoch 289/400, Validation Loss: 3.623523899007471
# Epoch 290/400, Validation Loss: 3.604313471411815
# Epoch 291/400, Validation Loss: 3.586400191442837
# Epoch 292/400, Validation Loss: 3.585563382242652
# Epoch 293/400, Validation Loss: 3.59933369006702
# Epoch 294/400, Validation Loss: 3.581710354319875
# Epoch 295/400, Validation Loss: 3.585826522864262
# Epoch 296/400, Validation Loss: 3.577334427681072
# Epoch 297/400, Validation Loss: 3.575245858450367
# Epoch 298/400, Validation Loss: 3.5745528165499274
# Epoch 299/400, Validation Loss: 3.571685127145964
# Epoch 300/400, Validation Loss: 3.572075216419118
# Epoch 301/400, Validation Loss: 3.568927953981877
# Epoch 302/400, Validation Loss: 3.5715903565590685
# Epoch 303/400, Validation Loss: 3.5693841032844382
# Epoch 304/400, Validation Loss: 3.56472347520274
# Epoch 305/400, Validation Loss: 3.5619576918739932
# Epoch 306/400, Validation Loss: 3.5615654897918225
# Epoch 307/400, Validation Loss: 3.5589645894465365
# Epoch 308/400, Validation Loss: 3.5573431217013094
# Epoch 309/400, Validation Loss: 3.56273658254536
# Epoch 310/400, Validation Loss: 3.5622072109050693
# Epoch 311/400, Validation Loss: 3.5528407317526964
# Epoch 312/400, Validation Loss: 3.551446655374284
# Epoch 313/400, Validation Loss: 3.5506432539708483
# Epoch 314/400, Validation Loss: 3.5637880760052147
# Epoch 315/400, Validation Loss: 3.555050243045227
# Epoch 316/400, Validation Loss: 3.5470780979671033
# Epoch 317/400, Validation Loss: 3.5467084260483674
# Epoch 318/400, Validation Loss: 3.5769190407928155
# Epoch 319/400, Validation Loss: 3.5522106529375668
# Epoch 320/400, Validation Loss: 3.5825183884101883
# Epoch 321/400, Validation Loss: 3.542024753734691
# Epoch 322/400, Validation Loss: 3.5395496510432722
# Epoch 323/400, Validation Loss: 3.5381526088159774
# Epoch 324/400, Validation Loss: 3.538616231352152
# Epoch 325/400, Validation Loss: 3.534390632037448
# Epoch 326/400, Validation Loss: 3.539712509389582
# Epoch 327/400, Validation Loss: 3.5337459468570978
# Epoch 328/400, Validation Loss: 3.539097041454673
# Epoch 329/400, Validation Loss: 3.552567486577124
# Epoch 330/400, Validation Loss: 3.543015463682264
# Epoch 331/400, Validation Loss: 3.5326520087477298
# Epoch 332/400, Validation Loss: 3.528931655316041
# Epoch 333/400, Validation Loss: 3.5251125910301235
# Epoch 334/400, Validation Loss: 3.524101769295804
# Epoch 335/400, Validation Loss: 3.5335587484792
# Epoch 336/400, Validation Loss: 3.540309593399628
# Epoch 337/400, Validation Loss: 3.5214214417829295
# Epoch 338/400, Validation Loss: 3.5206509319930577
# Epoch 339/400, Validation Loss: 3.5278580539054856
# Epoch 340/400, Validation Loss: 3.527390098284331
# Epoch 341/400, Validation Loss: 3.524229858379654
# Epoch 342/400, Validation Loss: 3.524857848031764
# Epoch 343/400, Validation Loss: 3.5207210183161677
# Epoch 344/400, Validation Loss: 3.5228400404322335
# Epoch 345/400, Validation Loss: 3.5353085316537274
# Epoch 346/400, Validation Loss: 3.5210498871337963
# Epoch 347/400, Validation Loss: 3.5222332608578752
# Epoch 348/400, Validation Loss: 3.5116882531712803
# Epoch 349/400, Validation Loss: 3.538027669505272
# Epoch 350/400, Validation Loss: 3.5098667215469916
# Epoch 351/400, Validation Loss: 3.5369836092088685
# Epoch 352/400, Validation Loss: 3.5323010981380234
# Epoch 353/400, Validation Loss: 3.547331874571287
# Epoch 354/400, Validation Loss: 3.5360827865709106
# Epoch 355/400, Validation Loss: 3.529528579400479
# Epoch 356/400, Validation Loss: 3.5255325420045933
# Epoch 357/400, Validation Loss: 3.526372646678061
# Epoch 358/400, Validation Loss: 3.5159368348768645
# Epoch 359/400, Validation Loss: 3.5071009329921545
# Epoch 360/400, Validation Loss: 3.5000252835857126
# Epoch 361/400, Validation Loss: 3.5037157405599886
# Epoch 362/400, Validation Loss: 3.50127457221634
# Epoch 363/400, Validation Loss: 3.5104169038888005
# Epoch 364/400, Validation Loss: 3.515085590163488
# Epoch 365/400, Validation Loss: 3.50161126971335
# Epoch 366/400, Validation Loss: 3.4972153390268574
# Epoch 367/400, Validation Loss: 3.498160460094803
# Epoch 368/400, Validation Loss: 3.4959832846961207
# Epoch 369/400, Validation Loss: 3.5276227237732853
# Epoch 370/400, Validation Loss: 3.518502614929151
# Epoch 371/400, Validation Loss: 3.5080903083852286
# Epoch 372/400, Validation Loss: 3.498067899989599
# Epoch 373/400, Validation Loss: 3.494372767209827
# Epoch 374/400, Validation Loss: 3.5018051124161587
# Epoch 375/400, Validation Loss: 3.4897689581262954
# Epoch 376/400, Validation Loss: 3.498933318148757
# Epoch 377/400, Validation Loss: 3.5145792239123237
# Epoch 378/400, Validation Loss: 3.488873732342845
# Epoch 379/400, Validation Loss: 3.489888469627637
# Epoch 380/400, Validation Loss: 3.4938534496708704
# Epoch 381/400, Validation Loss: 3.513764237747149
# Epoch 382/400, Validation Loss: 3.4874075730263234
# Epoch 383/400, Validation Loss: 3.501889239109773
# Epoch 384/400, Validation Loss: 3.483697378094507
# Epoch 385/400, Validation Loss: 3.4839411326774616
# Epoch 386/400, Validation Loss: 3.490963082818618
# Epoch 387/400, Validation Loss: 3.4831188123559222
# Epoch 388/400, Validation Loss: 3.4833533223775226
# Epoch 389/400, Validation Loss: 3.487546513521712
# Epoch 390/400, Validation Loss: 3.491773133945883
# Epoch 391/400, Validation Loss: 3.493324461463383
# Epoch 392/400, Validation Loss: 3.495823526453664
# Epoch 393/400, Validation Loss: 3.482308308411292
# Epoch 394/400, Validation Loss: 3.4898402162794797
# Epoch 395/400, Validation Loss: 3.483994290323583
# Epoch 396/400, Validation Loss: 3.4832460528841174
# Epoch 397/400, Validation Loss: 3.500286739514616
# Epoch 398/400, Validation Loss: 3.5052675126089823
# Epoch 399/400, Validation Loss: 3.4980351396011464
# Epoch 400/400, Validation Loss: 3.4756346352781025

# %%
a_val, b_val = model.a.item(), model.b.item()

# Generate predictions for plotting
end_fit_x = [x_all[0], x_all[-1]]
end_fit_y = [a_val * x + b_val for x in end_fit_x]
true_fn_y = [a0 * x + b0 for x in end_fit_x]  # Assuming a0 and b0 are known true values

# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plotting data points and model predictions
axs[0].plot(x_train, y_train, 'ro', x_val, y_val, 'b^', end_fit_x, end_fit_y, 'g')
axs[0].legend(('training points', 'test points', 'final fit'), loc='upper left')

# Assuming training and validation loss history are stored in lists: train_loss_history and val_loss_history
epochs = range(1, len(train_loss_history) + 1)

# Plotting loss history
axs[1].semilogy(epochs, train_loss_history, 'r')
axs[1].semilogy(epochs, val_loss_history, 'b')
axs[1].legend(('training loss', 'validation loss'), loc='upper right')

plt.show()

# %% [markdown]
# ## 3. Exercise 1
#
# Play with the true function parameters ```a0, b0, s0``` and the ``batch_size`` value, check how it affects the convergence.
#
# 1. How change of `s0` affects convergance?
# 2. When one should stop training to prevent overfitting?
#
#
# ## 4. Training loop
#
# The training as we just saw is done iteratively, by adjusting the model parameters.
#
# We perform optimization several times for all traininng dataset. Going through all this dataset is refered to as 'epoch'.
#
# When we do training its usually done in two loops. In outer loop we iterate over all epochs. For each epoch we usually split the dataset into small chuncks, batches, and optimization it performed for all of those.
#
# It is important that data doesn't go to the training pipeline in same order. So the overall scheme looks like this (pseudocode):
#
#
# ```
# x,y = get_training_data()
# for epoch in range(number_epochs):
#    x_shfl,y_shfl = shuffle(x,y)
#
#    for mb_idx in range(number_minibatches_in_batch):
#        x_mb,y_mb = get_minibatch(x_shfl,y_shfl, mb_idx)
#
#        optimize_on(data=x_mb, labels=y_mb)
# ```
#
# ## 5. Bulding blocks of a neural network
#
# Neural network consists of layers of neurons. Each neuron perfroms 2 operations.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/Perceptron.png" alt="drawing" width="30%"/>
#
# Each neuron performs 2 operations.
#
# 1. Calculate the linear transformation of the input vector $\mathbf{x}_i$:
# $$z_i = \mathbf{w} \cdot \mathbf{x}_i + b = \sum_j {w_j x_{ij}} + b$$ where $\mathbf{w}$ is a weight vector and $b$ - a bias, and $j$ traverses each dimension of the input vector
# 2. Perform the nonlinear transformation of the result using the activation function $f$ $$y_i = f(z_i)$$
#
# In a fully connected neural network, each layer is a set of N neurons, performing different transformations of the input $\mathbf{x}_i$ of the same layer, now producing an output **vector** $ \mathbf{y} _i = f(\mathbf{z}_i) = f(W\mathbf{x}_i + \mathbf{b})$ now with a bias vector $\mathbf{b}$ and a * *matrix** of weights $W$.
#
# Since the output of each layer constitutes the input to the next layer, we can write for layer $l$: $$\mathbf{x}^l_i = f^{l-1}(\mathbf{W}^{ l-1} \mathbf{x}^{ l-1}_i + \mathbf{b}^{l-1})$$ where $\mathbf{x}_i^{l=0}$ is the vector d 'network input for data point $i$.
#
# <img src="https://github.com/neworldemancer/BMLWS/raw/main/figures/MLP.png" alt="drawing" width="50%"/>
#
# To simplify building the network, we'll define a helper function, creating neuron layer with given number of outputs:

# %%
class Dense(nn.Module):
    def __init__(self, input_units, output_units, activation=None):
        """
        Fully connected layer implemented with explicit matrix multiplication.

        Parameters
        ----------
        input_units : int
            Number of input neurons
        output_units : int
            Number of output neurons
        activation : callable or None, optional
            Non-linear activation function (e.g., F.relu)
        """
        super(Dense, self).__init__()
        self.input_units = int(input_units)
        self.output_units = int(output_units)
        self.activation = activation

        # Initialize weights and biases
        self.weights = nn.Parameter(torch.randn(input_units, output_units))
        self.bias = nn.Parameter(torch.randn(output_units))

    def forward(self, x):
        """
        Forward pass through the layer.

        Parameters
        ----------
        x : torch.Tensor
            Input tensor

        Returns
        -------
        torch.Tensor
            Output of the layer
        """

        outputs = torch.matmul(x, self.weights) + self.bias

        # Apply activation function if provided
        if self.activation is not None:
            # Check if the activation function is softmax
            if self.activation == F.softmax:
                # Apply softmax with specified dimension
                outputs = self.activation(outputs, dim=1)
            else:
                # apply other activation functions normally
                outputs = self.activation(outputs)

        return outputs

# %% [markdown]
# In the case of multi-class classification, in the last layer, we can use the *softmax* transformation as a non-linear transformation. The softmax for the $j$th element of $\mathbf{z}_i$ is $$y_{ij} = \frac{e^{z_{ij}}}{\sum_{k=1}^{K} e^{z_{ik}}}$$ where $K$ is the total number of classes.
#
#
# For example. before softmax $$[1.0, 2.0, 3.0, \mathbf{4.0} ]$$ and after: $$[0.0321, 0.0871, 0.2369, \mathbf{0.6439}]$$ (now the sum is equal to one)
#
# We can also now compare the fundamental truth which could be $$[0,0,0,\mathbf{1}]$$ That is to say that class 4 is the good class and that the network predicted correctly.
# ## 6. Bulding a neural network
#
# https://medium.com/geekculture/how-visualizations-help-make-sense-of-deep-learning-a408ab00688f

# %%
n_input = 10
n_output = 2
num_datapoints = 1
input_tensor = torch.randn(num_datapoints, n_input)
dense = Dense(input_units=n_input , output_units=n_output, activation=torch.sigmoid)


# remember to matrix multiply A and B we need the shapes (a1 x a2) (b1 x b2) to be such that a2=b1
# the result will be (a1 x b2)

print(dense.weights.shape)
print(input_tensor.shape)
print(torch.matmul(input_tensor, dense.weights).shape) # this is XW  e.g. (1, 10)x(10, 2) = (1 x 2)

# notice that increasing the number of data points does not change the shape of W!
# This is important - the parameter shape should not change according to the number of datapoints, only their dimenaionality
# Out:
# torch.Size([10, 2])
# torch.Size([1, 10])
# torch.Size([1, 2])

# %%
# if we want to stack multiple dense operations together
hidden_dim = 10
dense1 =  Dense(input_units=n_input , output_units=hidden_dim, activation=torch.sigmoid)
dense2 =  Dense(input_units=hidden_dim , output_units=n_output, activation=F.softmax)
output = dense2(dense1(input_tensor))

print(output.shape)
# Out:
# torch.Size([1, 2])

# %%
# integrate everything into an overall model

class MyModel(nn.Module):
    def __init__(self, input_units, hidden_units, output_units):
        super(MyModel, self).__init__()
        # Define a Dense layer
        self.dense1 = Dense(input_units, hidden_units, activation=F.relu)
        # Define another Dense layer
        self.dense2 = Dense(hidden_units, output_units, activation=F.softmax)

    def forward(self, x):
        return self.dense2(self.dense1(x))

    def predict(self, x):
        # Forward pass and get predictions
        preds = self.dense2(self.dense1(x))
        print(preds)  # to check values before argmax
        preds = torch.argmax(preds, dim=1)
        for pred in preds:
          if pred.item() == 0:
            print('cat')
          elif pred.item() == 1:
            print('dog')

        return preds

# Example usage
input_units = 10
hidden_units = 5
output_units = 2
model = MyModel(input_units, hidden_units, output_units)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
# Out:
# tensor([[3.1007e-03, 9.9690e-01],
#         [1.7659e-01, 8.2341e-01],
#         [5.5036e-04, 9.9945e-01],
#         [6.5163e-05, 9.9993e-01],
#         [9.0647e-01, 9.3529e-02]], grad_fn=<SoftmaxBackward0>)
# dog
# dog
# dog
# dog
# cat
# tensor([1, 1, 1, 1, 0])

# %% [markdown]
# ## Exercise:
#
# Modify the MyModel class to be more flexible and adaptive in terms of width and depth. For example, it could take in a list of layer-widths [10, 5, 3, 2] so that it can be easily modified to handle inputs and outputs of different shapes.
#
# Have a think about how to also parameterise the outcome activation function (e.g. if the output is binary, multiclass, or regression) so that end up with a flexible neural network class.
#
# We haven't covered it yet, but you might want to explore weight initialization too - e.g. take a look at Kaiming and Xavier/Glorot weight initializers.

# %%
class MyModel(nn.Module):
    def __init__(self, layer_widths, hidden_activation=F.relu, output_activation=F.softmax):
        super(MyModel, self).__init__()

        self.layers = nn.ModuleList()
        self.output_activation = output_activation

        # Create hidden layers
        # Loop up to the second-to-last element to form hidden layers
        for i in range(len(layer_widths) - 1):
            input_units = layer_widths[i]
            output_units = layer_widths[i+1]
            activation = hidden_activation if i < len(layer_widths) - 2 else output_activation
            self.layers.append(Dense(input_units, output_units, activation=activation))

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

    def predict(self, x):
        # Forward pass to get raw outputs or final outputs after activation
        outputs = self.forward(x)
        print(outputs)

        # Handle classification predictions if output_activation is softmax
        if self.layers[-1].activation == F.softmax:
            preds = torch.argmax(outputs, dim=1)
            # Generalized prediction interpretation
            for pred in preds:
              if pred.item() == 0:
                print('cat')
              elif pred.item() == 1:
                print('dog')
            return preds
        else:
            # For regression or other tasks, return the outputs directly
            print("output is not softmax")
            return outputs

# Example usage
input_units = 10
output_units = 2

example_layer_widths = [input_units, 5, 3, output_units]

model = MyModel(layer_widths=example_layer_widths, output_activation=F.softmax)

# Create a sample input tensor
input_tensor = torch.randn(5, input_units)

# Get predictions
predictions = model.predict(input_tensor)
print(predictions)
# Out:
# tensor([[3.1839e-02, 9.6816e-01],
#         [5.7408e-04, 9.9943e-01],
#         [4.0319e-04, 9.9960e-01],
#         [8.8380e-05, 9.9991e-01],
#         [2.0647e-01, 7.9353e-01]], grad_fn=<SoftmaxBackward0>)
# dog
# dog
# dog
# dog
# dog
# tensor([1, 1, 1, 1, 1])
